# %%
import pandas as pd
import numpy as np

# %%
path = r"C:\ALLIMPORTS"

# %%
df=pd.read_csv(path+'''\\20200306 Data International Women's Day Viz5 Launch.csv''')

# %%
df
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 1             1  Afghanistan      F             Education
# 2             1  Afghanistan      F             Education
# 3             1  Afghanistan      F             Education
# 4             1  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12595       210     Zimbabwe      M             Residence
# 12596       280     Zimbabwe      M             Residence
# 12597       280     Zimbabwe      M             Residence
# 12598       350     Zimbabwe      M             Residence
# 12599       350     Zimbabwe      M             Residence
#
#               Demographics Response                                 Question  \
# 0                     Never married                ... if she burns the food
# 1                            Higher                ... if she burns the food
# ...

# %%
df['Question'].sample(10)
# Out:
# 8050     ... if she refuses to have sex with him
# 6645     ... if she refuses to have sex with him
# 10996    ... if she refuses to have sex with him
# 6862                  ... if she argues with him
# 9153                  ... if she argues with him
# 10913                 ... if she argues with him
# 5302        ... for at least one specific reason
# 2546                   ... if she burns the food
# 3539     ... if she refuses to have sex with him
# 790                   ... if she argues with him
# Name: Question, dtype: object

# %%
df[df.Country=='India'].sample(20)
# Out:
#       RecordID Country Gender Demographics Question  \
# 5729       242   India      M            Employment
# 5621       242   India      F                   Age
# 5730       242   India      M            Employment
# 5737       382   India      M        Marital status
# 5589        32   India      F             Education
# 5645       382   India      F            Employment
# 5602        32   India      M                   Age
# 5605        32   India      M                   Age
# 5738       102   India      M        Marital status
# 5606        32   India      M        Marital status
# 5644       312   India      F             Education
# 5658       312   India      F            Employment
# 5757       242   India      M             Residence
# 5693       172   India      M                   Age
# 5636       172   India      F             Education
# 5598        32   India      M        Marital status
# 5758       312   India      M             Residence
# ...

# %%
df[df["Country"] == "India"]
# Out:
#       RecordID Country Gender Demographics Question Demographics Response  \
# 5580        32   India      F             Education                Higher
# 5581        32   India      F             Residence                 Urban
# 5582        32   India      F        Marital status         Never married
# 5583        32   India      F             Education             Secondary
# 5584        32   India      F                   Age                 15-24
# ...        ...     ...    ...                   ...                   ...
# 5755       172   India      M             Residence                 Urban
# 5756       242   India      M             Residence                 Rural
# 5757       242   India      M             Residence                 Urban
# 5758       312   India      M             Residence                 Rural
# 5759       312   India      M             Residence                 Urban
#
#                                      Question Survey Year  Value
# ...

# %%
df.head(3)
# Out:
#    RecordID      Country Gender Demographics Question Demographics Response  \
# 0         1  Afghanistan      F        Marital status         Never married
# 1         1  Afghanistan      F             Education                Higher
# 2         1  Afghanistan      F             Education             Secondary
#
#                     Question Survey Year  Value
# 0  ... if she burns the food  01/01/2015    NaN
# 1  ... if she burns the food  01/01/2015   10.1
# 2  ... if she burns the food  01/01/2015   13.7

# %%
df.tail(3)
# Out:
#        RecordID   Country Gender Demographics Question Demographics Response  \
# 12597       280  Zimbabwe      M             Residence                 Urban
# 12598       350  Zimbabwe      M             Residence                 Rural
# 12599       350  Zimbabwe      M             Residence                 Urban
#
#                                       Question Survey Year  Value
# 12597         ... if she neglects the children  01/01/2015   15.0
# 12598  ... if she refuses to have sex with him  01/01/2015    7.2
# 12599  ... if she refuses to have sex with him  01/01/2015    3.7

# %%
df['Country'].nunique()
# Out:
# 70

# %%
df.select_dtypes(include='object').columns
# Out:
# Index(['Country', 'Gender', 'Demographics Question', 'Demographics Response',
#        'Question', 'Survey Year'],
#       dtype='object')

# %%
for i in df.select_dtypes(include = 'object').columns:
    print("Unique values in column:"+i)
    print(sorted(df[i].unique()))
    print("--"*30)
    print("")
# Out:
# Unique values in column:Country
# ['Afghanistan', 'Albania', 'Angola', 'Armenia', 'Azerbaijan', 'Bangladesh', 'Benin', 'Bolivia', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon', 'Chad', 'Colombia', 'Comoros', 'Congo', 'Congo Democratic Republic', "Cote d'Ivoire", 'Dominican Republic', 'Egypt', 'Eritrea', 'Eswatini', 'Ethiopia', 'Gabon', 'Gambia', 'Ghana', 'Guatemala', 'Guinea', 'Guyana', 'Haiti', 'Honduras', 'India', 'Indonesia', 'Jordan', 'Kenya', 'Kyrgyz Republic', 'Lesotho', 'Liberia', 'Madagascar', 'Malawi', 'Maldives', 'Mali', 'Moldova', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia', 'Nepal', 'Nicaragua', 'Niger', 'Nigeria', 'Pakistan', 'Peru', 'Philippines', 'Rwanda', 'Sao Tome and Principe', 'Senegal', 'Sierra Leone', 'South Africa', 'Tajikistan', 'Tanzania', 'Timor-Leste', 'Togo', 'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine', 'Yemen', 'Zambia', 'Zimbabwe']
# ------------------------------------------------------------
#
# Unique values in column:Gender
# ['F', 'M']
# ...

# %%
df.isna().sum()
# Out:
# RecordID                    0
# Country                     0
# Gender                      0
# Demographics Question       0
# Demographics Response       0
# Question                    0
# Survey Year                 0
# Value                    1413
# dtype: int64

# %%
miss=df[df.Value.isna()].Question.unique()
miss
# Out:
# array(['... if she burns the food',
#        '... for at least one specific reason',
#        '... if she argues with him',
#        '... if she goes out without telling him',
#        '... if she neglects the children',
#        '... if she refuses to have sex with him'], dtype=object)

# %%
df["Question"].unique()
# Out:
# array(['... if she burns the food',
#        '... for at least one specific reason',
#        '... if she argues with him',
#        '... if she goes out without telling him',
#        '... if she neglects the children',
#        '... if she refuses to have sex with him'], dtype=object)

# %%
print(df.shape)
df=df[~df.Country.isin(miss)]
print(df.shape)
# Out:
# (12600, 8)
# (12600, 8)

# %%
miss1 = df[df["Question"] == "NaN"]
miss1
print(df.isna().sum())
# Out:
# RecordID                    0
# Country                     0
# Gender                      0
# Demographics Question       0
# Demographics Response       0
# Question                    0
# Survey Year                 0
# Value                    1413
# dtype: int64

# %%
df.Country.count()
# Out:
# 12600

# %%
df[df.Value.isna()]
# Out:
#        RecordID      Country Gender Demographics Question  \
# 0             1  Afghanistan      F        Marital status
# 15            1  Afghanistan      M        Marital status
# 81          351  Afghanistan      F        Marital status
# 84           71  Afghanistan      F        Marital status
# 87          141  Afghanistan      F        Marital status
# ...         ...          ...    ...                   ...
# 12235       208        Yemen      M             Residence
# 12236       278        Yemen      M             Residence
# 12237       278        Yemen      M             Residence
# 12238       348        Yemen      M             Residence
# 12239       348        Yemen      M             Residence
#
#       Demographics Response                                 Question  \
# 0             Never married                ... if she burns the food
# 15            Never married                ... if she burns the food
# ...

# %%
miss = df[ df.Value.isna() ].Country.nunique()
miss
# Out:
# 26

# %%
print(df.shape)
df = df[ ~df.Country.isin( miss ) ]
print(df.shape)
# Out:
# (12600, 8)
# (7920, 8)

# %%
vm = df[df["Value"].isna()].Country.unique()

# %%
vm.shape
# Out:
# (26,)

# %%
df['Question'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 180                    ... if she burns the food
# 181                    ... if she burns the food
# 182                    ... if she burns the food
# 183                    ... if she burns the food
# 184                    ... if she burns the food
#                           ...
# 12595    ... if she goes out without telling him
# 12596           ... if she neglects the children
# 12597           ... if she neglects the children
# 12598    ... if she refuses to have sex with him
# 12599    ... if she refuses to have sex with him
# Name: Question, Length: 7920, dtype: object>

# %%
df['Survey Year']=pd.to_datetime(df['Survey Year'])

# %%
df['Filt_Year'] = df['Survey Year'].dt.year

# %%
pd.pivot_table(df,index='Filt_Year',columns='Gender',values='Value',aggfunc='mean')
# Out:
# Gender             F          M
# Filt_Year
# 2006       10.698889  13.925556
# 2008       16.516667  15.728889
# 2009        7.981111   9.910000
# 2010       23.794444  16.992222
# 2011       19.858889  16.038889
# 2012       30.782222  14.774074
# 2013       29.435556  17.171944
# 2014       23.795556  14.579683
# 2015       17.697083  13.399444
# 2016       30.582222  18.162778
# 2017       18.111481  10.195185
# 2018       49.688333  29.987778

# %%
pd.pivot_table(df,index='Question',columns='Gender',values='Value',aggfunc='mean')
# Out:
# Gender                                           F          M
# Question
# ... for at least one specific reason     39.598030  28.780606
# ... if she argues with him               23.710606  15.325152
# ... if she burns the food                13.120303   6.695606
# ... if she goes out without telling him  24.765303  15.055758
# ... if she neglects the children         29.265758  19.482727
# ... if she refuses to have sex with him  18.414848   9.455000

# %%
ind = df[ df['Country'] == 'India']

# %%
pd.pivot_table(ind, index='Question',columns='Gender', values = 'Value', aggfunc = 'mean')
# Out:
# Gender                                           F          M
# Question
# ... for at least one specific reason     45.020000  32.760000
# ... if she argues with him               29.386667  21.366667
# ... if she burns the food                19.506667  10.633333
# ... if she goes out without telling him  26.526667  16.693333
# ... if she neglects the children         33.146667  20.366667
# ... if she refuses to have sex with him  13.600000   9.520000

# %%
average_value = df.groupby('Country')['Value'].mean()
average_value.sort_values(ascending = False)
# Out:
# Country
# Timor-Leste                  46.210000
# Eritrea                      46.186667
# Morocco                      45.213333
# Tajikistan                   44.304444
# Afghanistan                  42.683333
# Chad                         42.436667
# Congo Democratic Republic    41.576111
# Guinea                       40.256111
# Mali                         39.420000
# Turkmenistan                 36.190000
# Congo                        34.908333
# Azerbaijan                   32.666071
# Tanzania                     29.567778
# Sierra Leone                 29.441111
# Niger                        29.211111
# Ethiopia                     28.392222
# Burundi                      27.692222
# Yemen                        27.621111
# Gambia                       26.373889
# Cote d'Ivoire                25.322222
# Uganda                       24.840556
# Pakistan                     24.435119
# Zambia                       24.361667
# Myanmar                      23.656667
# ...

# %%
average_value = df.groupby('Country')['Value'].mean().sort_values(ascending = False)
average_value

pd.set_option('display.max_rows', None)
average_value
# Out:
# Country
# Timor-Leste                  46.210000
# Eritrea                      46.186667
# Morocco                      45.213333
# Tajikistan                   44.304444
# Afghanistan                  42.683333
# Chad                         42.436667
# Congo Democratic Republic    41.576111
# Guinea                       40.256111
# Mali                         39.420000
# Turkmenistan                 36.190000
# Congo                        34.908333
# Azerbaijan                   32.666071
# Tanzania                     29.567778
# Sierra Leone                 29.441111
# Niger                        29.211111
# Ethiopia                     28.392222
# Burundi                      27.692222
# Yemen                        27.621111
# Gambia                       26.373889
# Cote d'Ivoire                25.322222
# Uganda                       24.840556
# Pakistan                     24.435119
# Zambia                       24.361667
# Myanmar                      23.656667
# ...

# %%
df.sort_values(by='Value',ascending=False).head(20)
# Out:
#        RecordID      Country Gender Demographics Question  \
# 66          351  Afghanistan      F            Employment
# 7783        394      Morocco      F            Employment
# 11023       412  Timor-Leste      F            Employment
# 7423        392         Mali      F            Employment
# 3666        371      Eritrea      F            Employment
# 7440        392         Mali      F        Marital status
# 95          351  Afghanistan      F             Residence
# 7399        392         Mali      F             Education
# 7818        394      Morocco      F             Residence
# 7422        392         Mali      F            Employment
# 31          351  Afghanistan      F                   Age
# 7381        392         Mali      F                   Age
# 7458        392         Mali      F             Residence
# 7382        392         Mali      F                   Age
# 46          351  Afghanistan      F             Education
# ...

# %%
df[df['Gender']=='F']['Value'].mean()
# Out:
# 24.812474747474745

# %%
df[df['Gender']=='M']['Value'].mean()
# Out:
# 15.799141414141413

# %%
df.sort_values('Value', ascending = False).head()
# Out:
#        RecordID      Country Gender Demographics Question  \
# 11023       412  Timor-Leste      F            Employment
# 7423        392         Mali      F            Employment
# 7440        392         Mali      F        Marital status
# 7399        392         Mali      F             Education
# 7422        392         Mali      F            Employment
#
#             Demographics Response                              Question  \
# 11023           Employed for kind  ... for at least one specific reason
# 7423            Employed for kind  ... for at least one specific reason
# 7440   Married or living together  ... for at least one specific reason
# 7399                 No education  ... for at least one specific reason
# 7422            Employed for cash  ... for at least one specific reason
#
#       Survey Year  Value  Filt_Year
# 11023  2016-01-01   85.2       2016
# 7423   2018-01-01   83.3       2018
# 7440   2018-01-01   82.1       2018
# ...

# %%
t = pd.pivot_table(df, index='Country', columns = 'Question', values = 'Value', aggfunc='mean')
t
# Out:
# Question                   ... for at least one specific reason  \
# Country
# Albania                                               10.883333
# Angola                                                22.640000
# Benin                                                 21.990000
# Burkina Faso                                          35.080000
# Burundi                                               45.806667
# Cambodia                                              35.960000
# Cameroon                                              41.143333
# Chad                                                  61.180000
# Colombia                                               4.646667
# Comoros                                               27.756667
# Congo Democratic Republic                             66.400000
# Cote d'Ivoire                                         43.126667
# Eswatini                                              25.450000
# ...

# %%
t.drop(columns = '... for at least one specific reason', inplace = True)
t
# Out:
# Question                   ... if she argues with him  \
# Country
# Albania                                      4.046667
# Angola                                      13.310000
# Benin                                       14.023333
# Burkina Faso                                22.433333
# Burundi                                     18.503333
# Cambodia                                    16.370000
# Cameroon                                    18.680000
# Chad                                        35.416667
# Colombia                                     1.536667
# Comoros                                     10.800000
# Congo Democratic Republic                   48.340000
# Cote d'Ivoire                               28.046667
# Eswatini                                    18.620000
# Ethiopia                                    26.166667
# Gabon                                       23.366667
# Gambia                                      17.043333
# ...

# %%
t['sum_le10']=(t<5).sum(axis=1)
t
# Out:
# Question                   ... if she argues with him  \
# Country
# Albania                                      4.046667
# Angola                                      13.310000
# Benin                                       14.023333
# Burkina Faso                                22.433333
# Burundi                                     18.503333
# Cambodia                                    16.370000
# Cameroon                                    18.680000
# Chad                                        35.416667
# Colombia                                     1.536667
# Comoros                                     10.800000
# Congo Democratic Republic                   48.340000
# Cote d'Ivoire                               28.046667
# Eswatini                                    18.620000
# Ethiopia                                    26.166667
# Gabon                                       23.366667
# Gambia                                      17.043333
# ...

# %%
t[ t['sum_le10'] == 5]
# Out:
# Question    ... if she argues with him  ... if she burns the food  \
# Country
# Albania                       4.046667                   0.883333
# Colombia                      1.536667                   1.336667
# Guatemala                     2.850000                   2.730000
# Haiti                         2.026667                   2.760000
# Honduras                      4.550000                   3.813333
# Malawi                        5.480000                   3.586667
# Mozambique                    7.410000                   3.836667
#
# Question    ... if she goes out without telling him  \
# Country
# Albania                                    6.356667
# Colombia                                   1.686667
# Guatemala                                  2.743333
# Haiti                                      8.780000
# Honduras                                   3.876667
# Malawi                                     5.276667
# ...

# %%
t.applymap(lambda x : x < 5).sum(axis = 1)
# Out:
# Country
# Albania                      4
# Angola                       1
# Benin                        1
# Burkina Faso                 1
# Burundi                      1
# Cambodia                     1
# Cameroon                     1
# Chad                         1
# Colombia                     5
# Comoros                      1
# Congo Democratic Republic    1
# Cote d'Ivoire                1
# Eswatini                     3
# Ethiopia                     1
# Gabon                        1
# Gambia                       1
# Ghana                        1
# Guatemala                    4
# Guinea                       1
# Guyana                       3
# Haiti                        4
# Honduras                     4
# India                        1
# Kenya                        1
# Lesotho                      1
# Liberia                      2
# Madagascar                   1
# Malawi                       2
# Mali                         1
# Mozambique                   2
# ...

# %%
t1 = pd.pivot_table(df, index='Country', columns = 'Question', values = 'Value', aggfunc='mean')

# %%
t1['sum_gt20'] = (t1 > 20).sum(axis=1)

# %%
t1[ t1['sum_gt20'] == 6]
# Out:
# Question     ... for at least one specific reason  ... if she argues with him  \
# Country
# Chad                                    61.180000                   35.416667
# Ethiopia                                42.166667                   26.166667
# Timor-Leste                             64.236667                   45.190000
#
# Question     ... if she burns the food  \
# Country
# Chad                         37.023333
# Ethiopia                     22.880000
# Timor-Leste                  25.566667
#
# Question     ... if she goes out without telling him  \
# Country
# Chad                                       42.666667
# Ethiopia                                   27.146667
# Timor-Leste                                55.470000
#
# Question     ... if she neglects the children  \
# Country
# Chad                                47.623333
# Ethiopia                            30.810000
# Timor-Leste                         55.010000
#
# ...
