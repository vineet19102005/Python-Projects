# %%
import pandas as pd
import numpy as np

# %%
bow=pd.read_csv(r"D:\Bowling\Bowling_ODI.csv")
bat=pd.read_csv(r"D:\Batting\ODI data.csv")

# %%
bat
# Out:
#       Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
# ...          ...                          ...        ...  ...  ...  ..    ...
# 2495          45              ZS Ansari (ENG)  2015-2015    1    -   -      -
# 2496          46         Ariful Haque (BDESH)  2018-2018    1    -   -      -
# 2497          47           Ashfaq Ahmed (PAK)  1994-1994    3    -   -      -
# 2498          48               MD Bailey (NZ)  1998-1998    1    -   -      -
# 2499          49               GR Beard (AUS)  1981-1981    2    -   -      -
#
# ...

# %%
print(bow.head(3))
print('--'*35)
print(bat.head(3))
# Out:
#    Unnamed: 0                        Player       Span  Mat Inns  Balls  \
# 0           0  M Muralitharan (Asia/ICC/SL)  1993-2011  350  341  18811
# 1           1             Wasim Akram (PAK)  1984-2003  356  351  18186
# 2           2            Waqar Younis (PAK)  1989-2003  262  258  12698
#
#     Runs Wkts   BBI    Ave  Econ    SR   4   5  Unnamed: 13
# 0  12326  534  7/30  23.08  3.93  35.2  15  10          NaN
# 1  11812  502  5/15  23.52  3.89  36.2  17   6          NaN
# 2   9919  416  7/36  23.84  4.68  30.5  14  13          NaN
# ----------------------------------------------------------------------
#    Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0           0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1           1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2           2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
#
#      HS    Ave     BF     SR 100  50   0  Unnamed: 13
# ...

# %%
bow.drop(columns=['Unnamed: 13'],inplace=True)

# %%
bow
# Out:
#       Unnamed: 0                        Player       Span  Mat Inns  Balls  \
# 0              0  M Muralitharan (Asia/ICC/SL)  1993-2011  350  341  18811
# 1              1             Wasim Akram (PAK)  1984-2003  356  351  18186
# 2              2            Waqar Younis (PAK)  1989-2003  262  258  12698
# 3              3          WPUJC Vaas (Asia/SL)  1994-2008  322  320  15775
# 4              4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398  372  17670
# ...          ...                           ...        ...  ...  ...    ...
# 2577          27              TJ Zoehrer (AUS)  1986-1994   22    -      -
# 2578          28                  K Zondo (SA)  2018-2018    5    -      -
# 2579          29              B Zuiderent (NL)  1996-2011   57    -      -
# 2580          30              Zulqarnain (PAK)  1985-1989   16    -      -
# 2581          31       Zulqarnain Haider (PAK)  2010-2010    4    -      -
#
#        Runs Wkts   BBI    Ave  Econ    SR   4   5
# ...

# %%
bat.drop(columns=['Unnamed: 13'],inplace=True)

# %%
bat.replace('-',-1,inplace=True)

# %%
bat
# Out:
#       Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
# ...          ...                          ...        ...  ...  ...  ..    ...
# 2495          45              ZS Ansari (ENG)  2015-2015    1   -1  -1     -1
# 2496          46         Ariful Haque (BDESH)  2018-2018    1   -1  -1     -1
# 2497          47           Ashfaq Ahmed (PAK)  1994-1994    3   -1  -1     -1
# 2498          48               MD Bailey (NZ)  1998-1998    1   -1  -1     -1
# 2499          49               GR Beard (AUS)  1981-1981    2   -1  -1     -1
#
# ...

# %%
bat['is_na']=(bat == -1).sum(axis=1)
bat
# Out:
#       Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
# ...          ...                          ...        ...  ...  ...  ..    ...
# 2495          45              ZS Ansari (ENG)  2015-2015    1   -1  -1     -1
# 2496          46         Ariful Haque (BDESH)  2018-2018    1   -1  -1     -1
# 2497          47           Ashfaq Ahmed (PAK)  1994-1994    3   -1  -1     -1
# 2498          48               MD Bailey (NZ)  1998-1998    1   -1  -1     -1
# 2499          49               GR Beard (AUS)  1981-1981    2   -1  -1     -1
#
# ...

# %%
bat.iloc[:,-11].appymap(lambda x:x==-1)

# %%
bat.isna().sum(axis=1)

# %%
bat=bat[bat['is_na']<=7]

# %%
bat.replace(-1,np.nan,inplace=True)
bat
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\3091432343.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bat.replace(-1,np.nan,inplace=True)
#       Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
# ...          ...                          ...        ...  ...  ...  ..    ...
# 2485          35           Tanvir Mehdi (PAK)  1992-1992    1    1   0      0
# ...

# %%
bow.replace('-',-1,inplace=True)
bow
# Out:
#       Unnamed: 0                        Player       Span  Mat Inns  Balls  \
# 0              0  M Muralitharan (Asia/ICC/SL)  1993-2011  350  341  18811
# 1              1             Wasim Akram (PAK)  1984-2003  356  351  18186
# 2              2            Waqar Younis (PAK)  1989-2003  262  258  12698
# 3              3          WPUJC Vaas (Asia/SL)  1994-2008  322  320  15775
# 4              4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398  372  17670
# ...          ...                           ...        ...  ...  ...    ...
# 2577          27              TJ Zoehrer (AUS)  1986-1994   22   -1     -1
# 2578          28                  K Zondo (SA)  2018-2018    5   -1     -1
# 2579          29              B Zuiderent (NL)  1996-2011   57   -1     -1
# 2580          30              Zulqarnain (PAK)  1985-1989   16   -1     -1
# 2581          31       Zulqarnain Haider (PAK)  2010-2010    4   -1     -1
#
#        Runs Wkts   BBI    Ave  Econ    SR   4   5
# ...

# %%
bow.replace('-1',np.nan,inplace=True)
bow

# %%
bow=bow[bow.isna().sum(axis=1)<=7]

# %%
bow

# %%
bow.replace('-',-1,inplace=True)
bow

# %%
bow['is_na']=(bow == -1).sum(axis=1)
bow
# Out:
#       Unnamed: 0                        Player       Span  Mat Inns  Balls  \
# 0              0  M Muralitharan (Asia/ICC/SL)  1993-2011  350  341  18811
# 1              1             Wasim Akram (PAK)  1984-2003  356  351  18186
# 2              2            Waqar Younis (PAK)  1989-2003  262  258  12698
# 3              3          WPUJC Vaas (Asia/SL)  1994-2008  322  320  15775
# 4              4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398  372  17670
# ...          ...                           ...        ...  ...  ...    ...
# 2577          27              TJ Zoehrer (AUS)  1986-1994   22   -1     -1
# 2578          28                  K Zondo (SA)  2018-2018    5   -1     -1
# 2579          29              B Zuiderent (NL)  1996-2011   57   -1     -1
# 2580          30              Zulqarnain (PAK)  1985-1989   16   -1     -1
# 2581          31       Zulqarnain Haider (PAK)  2010-2010    4   -1     -1
#
#        Runs Wkts   BBI    Ave  Econ    SR   4   5  is_na
# ...

# %%
bow=bow[bow['is_na']<=7]
bow
# Out:
#       Unnamed: 0                        Player       Span  Mat Inns  Balls  \
# 0              0  M Muralitharan (Asia/ICC/SL)  1993-2011  350  341  18811
# 1              1             Wasim Akram (PAK)  1984-2003  356  351  18186
# 2              2            Waqar Younis (PAK)  1989-2003  262  258  12698
# 3              3          WPUJC Vaas (Asia/SL)  1994-2008  322  320  15775
# 4              4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398  372  17670
# ...          ...                           ...        ...  ...  ...    ...
# 1868          18            Yasir Hameed (PAK)  2003-2007   56    3     18
# 1869          19           Zakir Hasan (BDESH)  1997-1997    1    1     12
# 1870          20         Zakir Hossain (BDESH)  1998-1998    1    1     24
# 1871          21          Zakiullah Zaki (AFG)  2012-2012    1    1     24
# 1872          22                C Zhuwao (ZIM)  2008-2018    9    2     19
#
#        Runs Wkts   BBI    Ave  Econ    SR   4   5  is_na
# ...

# %%
bow.replace(-1,np.nan,inplace=True)
bow
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\127324090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bow.replace(-1,np.nan,inplace=True)
#       Unnamed: 0                        Player       Span  Mat Inns  Balls  \
# 0              0  M Muralitharan (Asia/ICC/SL)  1993-2011  350  341  18811
# 1              1             Wasim Akram (PAK)  1984-2003  356  351  18186
# 2              2            Waqar Younis (PAK)  1989-2003  262  258  12698
# 3              3          WPUJC Vaas (Asia/SL)  1994-2008  322  320  15775
# 4              4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398  372  17670
# ...          ...                           ...        ...  ...  ...    ...
# 1868          18            Yasir Hameed (PAK)  2003-2007   56    3     18
# ...

# %%
bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2490 entries, 0 to 2489
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2490 non-null   int64
#  1   Player      2490 non-null   object
#  2   Span        2490 non-null   object
#  3   Mat         2490 non-null   int64
#  4   Inns        2490 non-null   object
#  5   NO          2490 non-null   object
#  6   Runs        2490 non-null   object
#  7   HS          2490 non-null   object
#  8   Ave         2370 non-null   object
#  9   BF          2490 non-null   object
#  10  SR          2481 non-null   object
#  11  100         2490 non-null   object
#  12  50          2490 non-null   object
#  13  0           2490 non-null   object
#  14  is_na       2490 non-null   int64
# dtypes: int64(3), object(12)
# memory usage: 311.2+ KB

# %%
bat

# %%
bow['is_na']=bow.isna().sum(axis=1)
bow

# %%
bow

# %%
bow=bow[bow.isna().sum(axis=1)<=7]
bow

# %%
bat['HS']=bat['HS'].apply(lambda x: str(x).removesuffix('*'))
bat

# %%
bat['HS'] = bat['HS'].str.rstrip('*')
bat
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\8090361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bat['HS'] = bat['HS'].str.rstrip('*')
#       Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
# ...          ...                          ...        ...  ...  ...  ..    ...
# ...

# %%
 bat[bat.columns[3:]]=bat[bat.columns[3:]].apply(pd.to_numeric)
bat
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\3759848649.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bat[bat.columns[3:]]=bat[bat.columns[3:]].apply(pd.to_numeric)
#       Unnamed: 0                       Player       Span  Mat  Inns  NO  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463   452  41
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375   365  39
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39
# ...          ...                          ...        ...  ...   ...  ..
# ...

# %%
bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2490 entries, 0 to 2489
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  2490 non-null   int64
#  1   Player      2490 non-null   object
#  2   Span        2490 non-null   object
#  3   Mat         2490 non-null   int64
#  4   Inns        2490 non-null   int64
#  5   NO          2490 non-null   int64
#  6   Runs        2490 non-null   int64
#  7   HS          2490 non-null   int64
#  8   Ave         2370 non-null   float64
#  9   BF          2490 non-null   int64
#  10  SR          2481 non-null   float64
#  11  100         2490 non-null   int64
#  12  50          2490 non-null   int64
#  13  0           2490 non-null   int64
#  14  is_na       2490 non-null   int64
# dtypes: float64(2), int64(11), object(2)
# memory usage: 311.2+ KB

# %%
filt=bat[bat['Inns'] >= 50]
filt
# Out:
#       Unnamed: 0                       Player       Span  Mat  Inns  NO  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463   452  41
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375   365  39
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39
# ...          ...                          ...        ...  ...   ...  ..
# 889           39       CRD Fernando (Asia/SL)  2001-2012  147    61  35
# 914           14                M Dillon (WI)  1997-2005  108    51  20
# 923           23           BKV Prasad (INDIA)  1994-2001  161    63  31
# 1102           2        Rubel Hossain (BDESH)  2009-2019  101    52  24
# 1187          37         GD McGrath (AUS/ICC)  1993-2007  250    68  38
#
#        Runs   HS    Ave     BF     SR  100  50   0  is_na
# ...

# %%
filt_p=filt.sort_values(by='Runs',ascending=False)

# %%
filt_p
# Out:
#       Unnamed: 0                       Player       Span  Mat  Inns  NO  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463   452  41
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375   365  39
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39
# ...          ...                          ...        ...  ...   ...  ..
# 889           39       CRD Fernando (Asia/SL)  2001-2012  147    61  35
# 914           14                M Dillon (WI)  1997-2005  108    51  20
# 923           23           BKV Prasad (INDIA)  1994-2001  161    63  31
# 1102           2        Rubel Hossain (BDESH)  2009-2019  101    52  24
# 1187          37         GD McGrath (AUS/ICC)  1993-2007  250    68  38
#
#        Runs   HS    Ave     BF     SR  100  50   0  is_na
# ...

# %%
filt_p['Filt_Centuries']=filt_p['100']+np.ceil(filt_p['50']/2)
filt_p
# Out:
#       Unnamed: 0                       Player       Span  Mat  Inns  NO  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463   452  41
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375   365  39
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39
# ...          ...                          ...        ...  ...   ...  ..
# 889           39       CRD Fernando (Asia/SL)  2001-2012  147    61  35
# 914           14                M Dillon (WI)  1997-2005  108    51  20
# 923           23           BKV Prasad (INDIA)  1994-2001  161    63  31
# 1102           2        Rubel Hossain (BDESH)  2009-2019  101    52  24
# 1187          37         GD McGrath (AUS/ICC)  1993-2007  250    68  38
#
#        Runs   HS    Ave     BF     SR  100  50   0  is_na  Filt_Centuries
# ...

# %%
bow[bow.columns[3:7]]=bow[bow.columns[3:7]].apply(pd.to_numeric)
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\3442975972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bow[bow.columns[3:7]]=bow[bow.columns[3:7]].apply(pd.to_numeric)

# %%
bow[bow.columns[9:]]=bow[bow.columns[9:]].apply(pd.to_numeric)
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\3757406110.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bow[bow.columns[9:]]=bow[bow.columns[9:]].apply(pd.to_numeric)

# %%
filtert=bow[bow['Inns']>=100]
filtert
# Out:
#      Unnamed: 0                        Player       Span  Mat  Inns  Balls  \
# 0             0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811
# 1             1             Wasim Akram (PAK)  1984-2003  356   351  18186
# 2             2            Waqar Younis (PAK)  1989-2003  262   258  12698
# 3             3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775
# 4             4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670
# ..          ...                           ...        ...  ...   ...    ...
# 225          25             SC Williams (ZIM)  2005-2019  131   107   4080
# 232          32                JP Duminy (SA)  2004-2019  199   135   3513
# 237          37              RR Singh (INDIA)  1989-2001  136   117   3734
# 286          36               MJ Clarke (AUS)  2003-2015  245   106   2585
# 422          22              SK Raina (INDIA)  2005-2018  226   101   2126
#
#       Runs Wkts   BBI    Ave  Econ    SR   4   5  is_na
# ...

# %%
filtert.sort_values(by='Wkts', ascending=False)
# Out:
#      Unnamed: 0                     Player       Span  Mat  Inns  Balls  Runs  \
# 150           0              NJ Astle (NZ)  1995-2007  223   159   4850  3809
# 154           4            N Boje (Afr/SA)  1995-2005  115   108   4541  3415
# 157           7  V Sehwag (Asia/ICC/INDIA)  1999-2013  251   146   4392  3853
# 172          22         Saleem Malik (PAK)  1982-1999  283   120   3505  2959
# 173          23            MN Samuels (WI)  2000-2018  207   134   5091  4127
# ..          ...                        ...        ...  ...   ...    ...   ...
# 133          33            TM Dilshan (SL)  1999-2016  330   204   5880  4778
# 132          32           PA de Silva (SL)  1984-2003  308   156   5148  4177
# 137          37            GW Flower (ZIM)  1992-2010  221   156   5462  4225
# 144          44     E Chigumbura (Afr/ZIM)  2004-2018  213   132   4339  4274
# 146          46    SC Ganguly (Asia/INDIA)  1992-2007  311   171   4561  3849
#
# ...

# %%
bow.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1873 entries, 0 to 1872
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1873 non-null   int64
#  1   Player      1873 non-null   object
#  2   Span        1873 non-null   object
#  3   Mat         1873 non-null   int64
#  4   Inns        1873 non-null   int64
#  5   Balls       1873 non-null   int64
#  6   Runs        1873 non-null   int64
#  7   Wkts        1873 non-null   object
#  8   BBI         1596 non-null   object
#  9   Ave         1596 non-null   float64
#  10  Econ        1873 non-null   float64
#  11  SR          1596 non-null   float64
#  12  4           1873 non-null   int64
#  13  5           1873 non-null   int64
#  14  is_na       1873 non-null   int64
# dtypes: float64(3), int64(8), object(4)
# memory usage: 234.1+ KB

# %%
bow['Wkts'] = pd.to_numeric(bow['Wkts'], errors='coerce')
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\3684371950.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bow['Wkts'] = pd.to_numeric(bow['Wkts'], errors='coerce')

# %%
average_balls = filtert['Balls'].mean()

filtered_bowl = filtert[filtert['Balls'] > average_balls]
filtered_bowl
# Out:
#     Unnamed: 0                         Player       Span  Mat  Inns  Balls  \
# 0            0   M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811
# 1            1              Wasim Akram (PAK)  1984-2003  356   351  18186
# 2            2             Waqar Younis (PAK)  1989-2003  262   258  12698
# 3            3           WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775
# 4            4   Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670
# 5            5        SM Pollock (Afr/ICC/SA)  1996-2008  303   297  15712
# 6            6           GD McGrath (AUS/ICC)  1993-2007  250   248  12970
# 7            7                    B Lee (AUS)  2000-2012  221   217  11185
# 8            8                SL Malinga (SL)  2004-2019  226   220  10936
# 9            9          A Kumble (Asia/INDIA)  1990-2007  271   265  14496
# 10          10        ST Jayasuriya (Asia/SL)  1989-2011  445   368  14874
# ...

# %%
bat['top_bat'] = np.where((bat['Mat'] > 100) & (bat['Runs'] > bat['Runs'].quantile(0.8)), 'Top', 'Okay')
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\1484232091.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bat['top_bat'] = np.where((bat['Mat'] > 100) & (bat['Runs'] > bat['Runs'].quantile(0.8)), 'Top', 'Okay')

# %%
bat
# Out:
#       Unnamed: 0                       Player       Span  Mat  Inns  NO  \
# 0              0         SR Tendulkar (INDIA)  1989-2012  463   452  41
# 1              1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404   380  41
# 2              2         RT Ponting (AUS/ICC)  1995-2012  375   365  39
# 3              3      ST Jayasuriya (Asia/SL)  1989-2011  445   433  18
# 4              4   DPMD Jayawardene (Asia/SL)  1998-2015  448   418  39
# ...          ...                          ...        ...  ...   ...  ..
# 2485          35           Tanvir Mehdi (PAK)  1992-1992    1     1   0
# 2486          36      M Venkataramana (INDIA)  1988-1988    1     1   1
# 2487          37              R Walters (NAM)  2003-2003    2     2   0
# 2488          38           CM Willoughby (SA)  2000-2003    3     2   0
# 2489          39        Zakir Hossain (BDESH)  1998-1998    1     1   0
#
#        Runs   HS    Ave     BF     SR  100  50   0  is_na top_bat
# ...

# %%
bow['top_bow'] = np.where((bow['Mat'] > 100) & (bow['Wkts'] > bow['Wkts'].quantile(0.8)), 'Top', 'Okay')
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\2841685417.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bow['top_bow'] = np.where((bow['Mat'] > 100) & (bow['Wkts'] > bow['Wkts'].quantile(0.8)), 'Top', 'Okay')

# %%
bow
# Out:
#       Unnamed: 0                        Player       Span  Mat  Inns  Balls  \
# 0              0  M Muralitharan (Asia/ICC/SL)  1993-2011  350   341  18811
# 1              1             Wasim Akram (PAK)  1984-2003  356   351  18186
# 2              2            Waqar Younis (PAK)  1989-2003  262   258  12698
# 3              3          WPUJC Vaas (Asia/SL)  1994-2008  322   320  15775
# 4              4  Shahid Afridi (Asia/ICC/PAK)  1996-2015  398   372  17670
# ...          ...                           ...        ...  ...   ...    ...
# 1868          18            Yasir Hameed (PAK)  2003-2007   56     3     18
# 1869          19           Zakir Hasan (BDESH)  1997-1997    1     1     12
# 1870          20         Zakir Hossain (BDESH)  1998-1998    1     1     24
# 1871          21          Zakiullah Zaki (AFG)  2012-2012    1     1     24
# 1872          22                C Zhuwao (ZIM)  2008-2018    9     2     19
#
# ...

# %%
bow["cleanname"] = bow["Player"].str.split("(", expand = True)[0].str.upper().str.replace(" ", "")
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\370450379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bow["cleanname"] = bow["Player"].str.split("(", expand = True)[0].str.upper().str.replace(" ", "")

# %%
bat["cleanname"] = bat["Player"].str.split("(", expand = True)[0].str.upper().str.replace(" ", "")
# Out:
# C:\Users\Shailesh Poojary\AppData\Local\Temp\ipykernel_8440\2883325389.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bat["cleanname"] = bat["Player"].str.split("(", expand = True)[0].str.upper().str.replace(" ", "")

# %%
df = pd.merge(bat[["cleanname", "top_bat"]], bow[["cleanname", "top_bow"]], how="inner" , on="cleanname")

# %%
df
# Out:
#             cleanname top_bat top_bow
# 0         SRTENDULKAR     Top     Top
# 1           RTPONTING     Top    Okay
# 2        STJAYASURIYA     Top     Top
# 3     DPMDJAYAWARDENE     Top    Okay
# 4      INZAMAM-UL-HAQ     Top    Okay
# ...               ...     ...     ...
# 1794         GSSOBERS    Okay    Okay
# 1795      TANVIRMEHDI    Okay    Okay
# 1796   MVENKATARAMANA    Okay    Okay
# 1797     CMWILLOUGHBY    Okay    Okay
# 1798     ZAKIRHOSSAIN    Okay    Okay
#
# [1799 rows x 3 columns]

# %%
df[(df['top_bat']=='Top')&(df['top_bow']=='Top')]
# Out:
#           cleanname top_bat top_bow
# 0       SRTENDULKAR     Top     Top
# 2      STJAYASURIYA     Top     Top
# 6          JHKALLIS     Top     Top
# 7         SCGANGULY     Top     Top
# 10          CHGAYLE     Top     Top
# ..              ...     ...     ...
# 343        RAHARPER     Top     Top
# 359           ZKHAN     Top     Top
# 360          GBHOGG     Top     Top
# 368     ABDURRAZZAK     Top     Top
# 384  SAQLAINMUSHTAQ     Top     Top
#
# [100 rows x 3 columns]
